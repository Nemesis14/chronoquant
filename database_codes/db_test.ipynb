# %%
# =============================================================================
# drop and recreate the sqlite database and bchusdt_1m table (composite pk)
# =============================================================================
import os
import sqlite3
import subprocess
import json

# =============================================================================
# database path and table name
# =============================================================================
repo_root = subprocess.check_output(["git", "rev-parse", "--show-toplevel"], text=True).strip()
DB_PATH   = json.load(open(os.path.join(repo_root, "config.json"), "r"))["db_path"]
table     = "bchusdt_1m"
print(DB_PATH)
# Out:
# D:/repos/chronoquant/data/bchusdt_data.db

# %%
import sqlite3
import pandas as pd 

# Adatbázis kapcsolat létrehozásaq
conn = sqlite3.connect(DB_PATH)

# Táblák lekérdezése
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
print(tables)

conn.close()
# Out:
#              name
# 0      bchusdt_1m
# 1  bchusdt_1m_dev

# %%
import sqlite3

conn = sqlite3.connect(DB_PATH)
conn.execute("DROP TABLE IF EXISTS bchusdt_data_dev;")
conn.commit()
conn.close()
