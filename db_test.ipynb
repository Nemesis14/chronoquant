# %% [markdown]
# # Connect to DB

# %%
# =============================================================================
# drop and recreate the sqlite database and bchusdt_1m table (composite pk)
# =============================================================================
import os
import sqlite3
import subprocess
import json
import utils as utils
import pandas as pd

# =============================================================================
# database path and table name
# =============================================================================
cfg          = utils._load_config()
DB_PATH      = cfg["database"]["db_path"]
print(DB_PATH)
# Out:
# D:/repos/chronoquant/data/bchusdt_data.db

# %% [markdown]
# # Select the tables

# %%
conn   = sqlite3.connect(DB_PATH)
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
conn.close()
print(tables)
# Out:
#              name
# 0      bchusdt_1m
# 1  bchusdt_1m_dev

# %% [markdown]
# # Select the data from BCHUSDT 1m table

# %%
# Adatbázis kapcsolat létrehozásaq
conn = sqlite3.connect(DB_PATH)
df   = pd.read_sql_query("SELECT * FROM bchusdt_1m;", conn)
conn.close()
df.head()
# Out:
#     open_time_ms         open_time    open    high     low   close    volume
# 0  1574935200000  2019-11-28 12:00  220.08  224.60  212.02  224.60   7.23587
# 1  1574935260000  2019-11-28 12:01  224.60  224.60  224.59  224.59   1.75804
# 2  1574935320000  2019-11-28 12:02  224.59  224.60  218.50  218.67  12.24359
# 3  1574935380000  2019-11-28 12:03  219.00  222.53  219.00  219.06  14.87814
# 4  1574935440000  2019-11-28 12:04  220.00  223.89  218.52  223.89  61.79853

# %% [markdown]
# # Select the data from BCHUSDT 1m DEV table

# %%
conn = sqlite3.connect(DB_PATH)
df   = pd.read_sql_query("SELECT * FROM bchusdt_1m_dev;", conn)
conn.close()
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File d:\programs\python\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: no such table: bchusdt_1m_dev
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 2
#       1 conn = sqlite3.connect(DB_PATH)
# ----> 2 df   = pd.read_sql_query("SELECT * FROM bchusdt_1m_dev;", conn)
#       3 conn.close()
#       4 df.head()
#
# File d:\programs\python\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File d:\programs\python\Lib\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File d:\programs\python\Lib\site-packages\pandas\io\sql.py:2686, in SQLiteDatabase.execute(self, sql, params)
#    2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM bchusdt_1m_dev;': no such table: bchusdt_1m_dev

# %% [markdown]
# # Drop table

# %%
import sqlite3

conn = sqlite3.connect(DB_PATH)
conn.execute("DROP TABLE IF EXISTS bchusdt_1m_dev;")
conn.commit()
conn.close()
