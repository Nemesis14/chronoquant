# %% [markdown]
# # ChronoQuant – Workflow Test
# Ezt a notebookot Claude generálta és Drive-ra másolta. Csak nyomd meg a **Run All** gombot (Ctrl+F9).

# %%
# 1. Drive csatolás
from google.colab import drive

drive.mount('/content/drive')
print('Drive: OK')

# %%
# 2. Test fájl beolvasása Drive-ról
with open('/content/drive/My Drive/chronoquant/hello.txt') as f:
    content = f.read().strip()
print(f'Drive fájl tartalma: {content}')

# %%
# 3. Python verzió
import sys

print(f'Python: {sys.version.split()[0]}')
print()
print('=== WORKFLOW TEST SIKERES ===')
