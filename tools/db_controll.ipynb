# %% [markdown]
# # Config info

# %%
# =============================================================================
# Load and display config info (notebook cell)
# =============================================================================

import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk

dbtk.print_config_summary()
# Out:
# ======================================================================
# DATABASE CONFIGURATION
# ======================================================================
#
# Active env: dev
#   Dev path:  D:/database/bchusdt_data_dev.db
#   Prod path: D:/database/bchusdt_data_prod.db
#
# Active DB Path:
#   D:/database/bchusdt_data_dev.db
#
# Tables:
#   [ohlcv]        bchusdt_1m
#   [features]     bchusdt_1m_features
#   [predictions]  bchusdt_1m_predictions
#
# ======================================================================

# %% [markdown]
# # DB tables info

# %%
# =============================================================================
# Query all tables from database: row count, min/max open_time
# =============================================================================

import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk

dbtk.print_tables_summary()
# Out:
# ================================================================================
# DATABASE TABLES SUMMARY (env=dev)
# ================================================================================
# Table Name                Rows         Min Date             Max Date
# --------------------------------------------------------------------------------
# bchusdt_1m                3248428      2019-11-28 10:00:00  2026-02-01 22:11:00
# bchusdt_1m_features       7309708      2019-11-28 10:00:00  2026-02-01 22:11:00
# bchusdt_1m_predictions    3249886      2019-11-28 10:00:00  2026-02-01 22:11:00
# ================================================================================

# %% [markdown]
# # Table info

# %%
# =============================================================================
# Database control: display tail
# =============================================================================

import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk
dbtk.tail('bchusdt_1m_features')
# Out:
# ================================================================================
# TABLE: bchusdt_1m_features (env=active)
# ================================================================================
# Total rows: 7311223
#
# Last 5 rows:
# --------------------------------------------------------------------------------
#           open_time  close  trg_long_rw_240_prc_09  feat_rsi_14  feat_roc_14  feat_roc_140  feat_macd_diff  feat_sma_ratio_14  feat_sma_ratio_140  feat_bb_width_14  feat_bb_width_140  trg_short_rw_240_prc_09
# 2026-02-02 07:26:00  510.9                       0    48.601827    -0.156342      0.314157       -0.236096           0.998980            1.009355          0.004331           0.029458                        0
# 2026-02-02 07:25:00  511.4                       0    51.473667    -0.273011      0.176298       -0.206595           0.999846            1.010365          0.004204           0.029336                        0
# 2026-02-02 07:24:00  511.5                       0    52.044790    -0.292398     -0.039085       -0.202265           0.999846            1.010576          0.004965           0.029266                        0
# 2026-02-02 07:23:00  511.7                       0    53.139780    -0.524883      0.412088       -0.198481           1.000028            1.010968          0.005720           0.029271                        0
# 2026-02-02 07:22:00  511.8                       0    53.663985    -0.466744      0.254652       -0.206802           0.999847            1.011196          0.007911           0.029123                        0
# ================================================================================

# %% [markdown]
# # Datatable validation

# %%
# =============================================================================
# Database control: validate table open_time integrity
# =============================================================================

import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk

# -------------------------------------------------------------------------
# Validate table
dbtk.validate_open_time('bchusdt_1m', max_issues=1000)
# dbtk.validate_open_time('bchusdt_1m_features')
# dbtk.validate_open_time('bchusdt_1m_predictions')
# Out:
# ======================================================================
# VALIDATING TABLE: bchusdt_1m (env=active)
# ======================================================================
#
# Total rows: 3248983
# Unique open_time values: 3248983
# open_time is unique
# VIOLATION: 17 gaps are NOT 1 minute!
#
# Issues found:
# Row 104639: 2020-02-09 01:59:00 -> 2020-02-09 03:00:00 (diff: 3660s)
# Row 119555: 2020-02-19 11:35:00 -> 2020-02-19 17:30:00 (diff: 21300s)
# Row 139227: 2020-03-04 09:21:00 -> 2020-03-04 11:30:00 (diff: 7740s)
# Row 213537: 2020-04-25 01:59:00 -> 2020-04-25 04:30:00 (diff: 9060s)
# Row 305547: 2020-06-28 01:59:00 -> 2020-06-28 05:30:00 (diff: 12660s)
# Row 528777: 2020-11-30 05:59:00 -> 2020-11-30 07:00:00 (diff: 3660s)
# Row 559425: 2020-12-21 13:47:00 -> 2020-12-21 18:00:00 (diff: 15180s)
# Row 564225: 2020-12-25 01:59:00 -> 2020-12-25 03:00:00 (diff: 3660s)
# Row 633386: 2021-02-11 03:40:00 -> 2021-02-11 05:00:00 (diff: 4800s)
# Row 666326: 2021-03-06 01:59:00 -> 2021-03-06 03:30:00 (diff: 5460s)
# Row 731036: 2021-04-20 01:59:00 -> 2021-04-20 04:30:00 (diff: 9060s)
# Row 738207: 2021-04-25 04:00:00 -> 2021-04-25 08:45:00 (diff: 17100s)
# Row 896202: 2021-08-13 01:59:00 -> 2021-08-13 06:30:00 (diff: 16260s)
# Row 963912: 2021-09-29 06:59:00 -> 2021-09-29 09:00:00 (diff: 7260s)
# Row 1743172: 2023-03-24 12:39:00 -> 2023-03-24 14:00:00 (diff: 4860s)
# Row 3113827: 2025-10-31 10:14:00 -> 2025-10-31 10:48:00 (diff: 2040s)
# Row 3113828: 2025-10-31 10:48:00 -> 2025-10-31 10:53:00 (diff: 300s)
#
# ======================================================================

# %% [markdown]
# # Drop tables

# %%
# =============================================================================
# Database control: drop table by name
# =============================================================================

import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk
# dbtk.drop_table('bchusdt_1m_features')

# %% [markdown]
# # Rename table column

# %%
# =============================================================================
# Rename column helper
# =============================================================================

import sys
sys.path.insert(0, "..")
import utils
import tools.db_toolkit as dbtk

# =============================================================================
# Apply target renames (dev + prod)
# =============================================================================

db_cfg            = utils.load_db_config()["database"]
table_features    = db_cfg["tables"]["features"]
table_predictions = db_cfg["tables"]["predictions"]

feat_cfg          = utils.load_features_config()
targets           = feat_cfg["database"]["features"]["targets"]
long_cfg          = next((t for t in targets if t.get("direction") == "long"), None)
if not long_cfg:
    raise ValueError("No long target config found")
long_name         = long_cfg["name"]

# dbtk.rename_column("dev" , table_features    , "target", long_name)
# dbtk.rename_column("dev" , table_predictions , "target", long_name)
# dbtk.rename_column("prod", table_features    , "target", long_name)
# dbtk.rename_column("prod", table_predictions , "target", long_name)

# %% [markdown]
# ## Add Missing Columns
#
# Use these helpers to add columns to any table (dev/prod) when the schema changes.

# %%
# =============================================================================
# Add column helper
# =============================================================================

import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk

# %% [markdown]
# ## Apply New Short Target Column
#
# This adds the new short target column to the features table in dev/prod.

# %%
import sys
sys.path.insert(0, "..")
import utils
import tools.db_toolkit as dbtk

db_cfg         = utils.load_db_config()["database"]
table_pred     = db_cfg["tables"]["predictions"]

feat_cfg       = utils.load_features_config()
targets        = feat_cfg["database"]["features"]["targets"]
short_cfg      = next((t for t in targets if t.get("direction") == "short"), None)
if not short_cfg:
    raise ValueError("No short target config found")
short_name     = short_cfg.get("name") or utils.target_col_name(
    "short",
    short_cfg["rolling_window"],
    short_cfg["percentile"]
)

# dbtk.add_column('dev' , table_pred, short_name, 'INTEGER')
# dbtk.add_column('prod', table_pred, short_name, 'INTEGER')

# %% [markdown]
# # Reset table

# %% [markdown]
# ## features

# %%
import sys
sys.path.insert(0, "..")

import utils
import tools.db_toolkit as dbtk
from app import settings
from database_codes.features import sync_features

# --- táblanevek / útvonal ---
db_cfg         = utils.load_db_config()["database"]
table_features = db_cfg["tables"]["features"]

# --- DROP features tábla ---
dbtk.drop_table(table_features)

# --- ÚJRA generálás ---
sync_features(settings.INIT_START_DATE)
# Out:
# Dropped table 'bchusdt_1m_features' (env=active)
# ✅ Computed 3251035 feature rows into 'bchusdt_1m_features'

# %%
# =============================================================================
# Database control: display tail
# =============================================================================
import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk
dbtk.tail('bchusdt_1m_features')
# Out:
# ================================================================================
# TABLE: bchusdt_1m_features (env=active)
# ================================================================================
# Total rows: 3251035
#
# Last 5 rows:
# --------------------------------------------------------------------------------
#           open_time  close  trg_l_rw_240_prc_09  trg_s_rw_240_prc_09  feat_rsi_14  feat_roc_14  feat_roc_140  feat_macd_diff  feat_sma_ratio_14  feat_sma_ratio_140  feat_bb_width_14  feat_bb_width_140
# 2026-02-03 17:38:00  521.1                    0                    0    26.917739    -0.591377     -0.382336       -0.171014           0.995646            0.988825          0.006642           0.020821
# 2026-02-03 17:37:00  522.2                    0                    0    33.009752    -0.400534     -0.133869       -0.077258           0.997326            0.990885          0.004704           0.020578
# 2026-02-03 17:36:00  522.7                    0                    0    36.496017    -0.305169      0.114921       -0.026769           0.997995            0.991824          0.003824           0.020495
# 2026-02-03 17:35:00  523.2                    0                    0    40.464328    -0.114548      0.538048        0.011277           0.998732            0.992781          0.003239           0.020532
# 2026-02-03 17:34:00  523.0                    0                    0    37.958701    -0.019117      0.345357        0.026193           0.998269            0.992439          0.002926           0.020833
# ================================================================================

# %% [markdown]
# ## predictions

# %%
import sys
sys.path.insert(0, "..")

import utils
import tools.db_toolkit as dbtk
from app import settings
from database_codes.predictions import sync_predictions

# --- táblanév ---
db_cfg          = utils.load_db_config()["database"]
table_pred      = db_cfg["tables"]["predictions"]

# --- DROP predictions tábla ---
dbtk.drop_table(table_pred)

# --- ÚJRA generálás ---
sync_predictions(settings.INIT_START_DATE)
# Out:
# Dropped table 'bchusdt_1m_predictions' (env=active)
# Inserted 3251035 predictions into 'bchusdt_1m_predictions' (lg_l_rw240_p90_base_sm_p, lg_s_rw240_p90_base_sm_p)

# %%
# =============================================================================
# Database control: display tail
# =============================================================================
import sys
sys.path.insert(0, '..')
import tools.db_toolkit as dbtk
dbtk.tail('bchusdt_1m_predictions')
# Out:
# ================================================================================
# TABLE: bchusdt_1m_predictions (env=active)
# ================================================================================
# Total rows: 3251035
#
# Last 5 rows:
# --------------------------------------------------------------------------------
#           open_time  close  trg_l_rw_240_prc_09  trg_s_rw_240_prc_09  lg_l_rw240_p90_base_sm_p  lg_s_rw240_p90_base_sm_p
# 2026-02-03 17:38:00  521.1                    0                    0                  0.089617                  0.106499
# 2026-02-03 17:37:00  522.2                    0                    0                  0.080998                  0.093794
# 2026-02-03 17:36:00  522.7                    0                    0                  0.077858                  0.087486
# 2026-02-03 17:35:00  523.2                    0                    0                  0.076181                  0.082554
# 2026-02-03 17:34:00  523.0                    0                    0                  0.074060                  0.083239
# ================================================================================
